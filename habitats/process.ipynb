# %%
import pandas as pd

df = pd.read_csv("habitats.csv", index_col="Unnamed: 0")
df
# Out:
#            species                            habitat
# 0        Bulbasaur      Kantonian forests and jungles
# 1          Ivysaur      Kantonian forests and jungles
# 2         Venusaur      Kantonian forests and jungles
# 3       Charmander  Kantonian mountains and volcanoes
# 4       Charmeleon  Kantonian mountains and volcanoes
# ...            ...                                ...
# 1003        Chi-Yu                              Ruins
# 1004  Roaring Moon                          Area Zero
# 1005  Iron Valiant                          Area Zero
# 1006      Koraidon                           Anywhere
# 1007      Miraidon                           Anywhere
#
# [1008 rows x 2 columns]

# %%
import numpy as np
import re

habitat_map = {
    "grassland": "field|grassland|plain|meadow|scrubland",
    "forest": "forest|jungle|woodland",
    "waters-edge": "beach|lake|estuarie|pond|riverside|swamp|tropical river|wetland",
    "sea": "ocean|sea",
    "cave": "cave",
    "mountain": "mountain|volcano",
    "rough-terrain": "badland|wasteland|desert|rocky|ruin",
    "urban": "building|computer|human|sewer|power plant|urban",
    "rare": "_"
}
for habitat, keywords in habitat_map.items():
    df[habitat] = df.habitat.str.contains(keywords, flags=re.IGNORECASE, regex=True)
df["has_habitat"] = df.any(bool_only=True, axis=1)

"""
Exceptions:
Eeveelutions: urban
Legendaries: rare
Unown: rare
CastforM: grassland
"""

df[df.has_habitat == False].head(50)
# Out:
#           species                                            habitat  \
# 134       Jolteon                               Arid, dry chaparrals
# 144        Zapdos       Secluded areas with high electrical activity
# 149        Mewtwo                     Anywhere, but prefers solitude
# 150           Mew                                           Anywhere
# 249         Ho-Oh                                        Clear skies
# 350      Castform  Areas with unpredictable weather, weather stat...
# 379        Latias                                         Near water
# 380        Latios                                         Near water
# 382       Groudon                                     Magma chambers
# 383      Rayquaza                                        Ozone layer
# 385        Deoxys                                 Meteor crash sites
# 479          Uxie                        Museums, libraries, schools
# 480       Mesprit                          Memorial sites, festivals
# ...

# %%
df[list(habitat_map)].all(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1003    False
# 1004    False
# 1005    False
# 1006    False
# 1007    False
# Length: 1008, dtype: bool
