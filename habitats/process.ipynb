# %%
import pandas as pd

df = pd.read_csv("habitats.csv", index_col="Unnamed: 0")
subs = [("♀", "-F"), ("♂", "-M"), ("'", "’"), ("Flabébé", "Flabébé"), ("Daschsbun", "Dachsbun")]
for old, new in subs:
    df["species"] = df.species.str.replace(old, new)
df
# Out:
#            species                            habitat
# 0        Bulbasaur      Kantonian forests and jungles
# 1          Ivysaur      Kantonian forests and jungles
# 2         Venusaur      Kantonian forests and jungles
# 3       Charmander  Kantonian mountains and volcanoes
# 4       Charmeleon  Kantonian mountains and volcanoes
# ...            ...                                ...
# 1003        Chi-Yu                              Ruins
# 1004  Roaring Moon                          Area Zero
# 1005  Iron Valiant                          Area Zero
# 1006      Koraidon                           Anywhere
# 1007      Miraidon                           Anywhere
#
# [1008 rows x 2 columns]

# %%
dex = pd.read_csv("../dex/dex.csv")
dex = dex[dex.num > 0]
dex = dex[~dex.forme.isin(["Mega", "Mega-X", "Mega-Y", "Primal", "Gmax"])]
dex = dex[["num", "name", "baseSpecies", "prevo", "legendary"]]
dex.baseSpecies.fillna(value=dex.name, inplace=True)
dex = dex.merge(right=dex[["name", "legendary"]], how="left", left_on="baseSpecies", right_on="name", suffixes=["_1", None])
dex.drop(columns=["name_1", "legendary_1"], inplace=True)
dex
# Out:
#        num   baseSpecies       prevo          name             legendary
# 0        1     Bulbasaur         NaN     Bulbasaur                   NaN
# 1        2       Ivysaur   Bulbasaur       Ivysaur                   NaN
# 2        3      Venusaur     Ivysaur      Venusaur                   NaN
# 3        4    Charmander         NaN    Charmander                   NaN
# 4        5    Charmeleon  Charmander    Charmeleon                   NaN
# ...    ...           ...         ...           ...                   ...
# 1213  1006  Iron Valiant         NaN  Iron Valiant               Paradox
# 1214  1007      Koraidon         NaN      Koraidon  Restricted Legendary
# 1215  1008      Miraidon         NaN      Miraidon  Restricted Legendary
# 1216  1009  Walking Wake         NaN  Walking Wake               Paradox
# 1217  1010   Iron Leaves         NaN   Iron Leaves               Paradox
#
# [1218 rows x 5 columns]

# %%
dex.columns
# Out:
# Index(['num', 'baseSpecies', 'prevo', 'name', 'legendary'], dtype='object')

# %%
dex = dex.merge(right=df, how="left", left_on="baseSpecies", right_on="species")
dex
# Out:
#        num   baseSpecies       prevo          name             legendary  \
# 0        1     Bulbasaur         NaN     Bulbasaur                   NaN
# 1        2       Ivysaur   Bulbasaur       Ivysaur                   NaN
# 2        3      Venusaur     Ivysaur      Venusaur                   NaN
# 3        4    Charmander         NaN    Charmander                   NaN
# 4        5    Charmeleon  Charmander    Charmeleon                   NaN
# ...    ...           ...         ...           ...                   ...
# 1213  1006  Iron Valiant         NaN  Iron Valiant               Paradox
# 1214  1007      Koraidon         NaN      Koraidon  Restricted Legendary
# 1215  1008      Miraidon         NaN      Miraidon  Restricted Legendary
# 1216  1009  Walking Wake         NaN  Walking Wake               Paradox
# 1217  1010   Iron Leaves         NaN   Iron Leaves               Paradox
#
#            species                            habitat
# 0        Bulbasaur      Kantonian forests and jungles
# 1          Ivysaur      Kantonian forests and jungles
# 2         Venusaur      Kantonian forests and jungles
# 3       Charmander  Kantonian mountains and volcanoes
# 4       Charmeleon  Kantonian mountains and volcanoes
# ...            ...                                ...
# 1213  Iron Valiant                          Area Zero
# 1214      Koraidon                           Anywhere
# 1215      Miraidon                           Anywhere
# 1216           NaN                                NaN
# 1217           NaN                                NaN
#
# [1218 rows x 7 columns]

# %%
import re

habitat_map = {
    "grassland": "field|grassland|plain|meadow|scrubland",
    "forest": "forest|jungle|woodland",
    "waters-edge": "beach|lake|estuarie|pond|riverside|swamp|tropical river|wetland",
    "sea": "coast|ocean|sea",
    "cave": "cave",
    "mountain": "glacier|mountain|peak|tundra|volcano",
    "rough-terrain": "badland|wasteland|desert|rocky|ruin",
    "urban": "building|computer|human|sewer|power plant|urban",
    "rare": "unknown"
}

for habitat, keywords in habitat_map.items():
    dex[habitat] = dex.habitat.str.contains(keywords, flags=re.IGNORECASE, regex=True)

dex.loc[dex.prevo == "Eevee", "urban"] = True
dex.loc[~dex.legendary.isna(), "rare"] = True
dex.loc[dex.baseSpecies == "Unown", "rare"] = True
dex.loc[dex.baseSpecies == "Castform", "grassland"] = True

dex["habitat_count"] = dex[list(habitat_map)].sum(axis=1)
dex
# Out:
#        num   baseSpecies       prevo          name             legendary  \
# 0        1     Bulbasaur         NaN     Bulbasaur                   NaN
# 1        2       Ivysaur   Bulbasaur       Ivysaur                   NaN
# 2        3      Venusaur     Ivysaur      Venusaur                   NaN
# 3        4    Charmander         NaN    Charmander                   NaN
# 4        5    Charmeleon  Charmander    Charmeleon                   NaN
# ...    ...           ...         ...           ...                   ...
# 1213  1006  Iron Valiant         NaN  Iron Valiant               Paradox
# 1214  1007      Koraidon         NaN      Koraidon  Restricted Legendary
# 1215  1008      Miraidon         NaN      Miraidon  Restricted Legendary
# 1216  1009  Walking Wake         NaN  Walking Wake               Paradox
# 1217  1010   Iron Leaves         NaN   Iron Leaves               Paradox
#
#            species                            habitat grassland forest  \
# 0        Bulbasaur      Kantonian forests and jungles     False   True
# 1          Ivysaur      Kantonian forests and jungles     False   True
# 2         Venusaur      Kantonian forests and jungles     False   True
# 3       Charmander  Kantonian mountains and volcanoes     False  False
# 4       Charmeleon  Kantonian mountains and volcanoes     False  False
# ...            ...                                ...       ...    ...
# 1213  Iron Valiant                          Area Zero     False  False
# 1214      Koraidon                           Anywhere     False  False
# 1215      Miraidon                           Anywhere     False  False
# 1216           NaN                                NaN       NaN    NaN
# 1217           NaN                                NaN       NaN    NaN
#
#      waters-edge    sea   cave mountain rough-terrain  urban   rare  \
# 0          False  False  False    False         False  False  False
# 1          False  False  False    False         False  False  False
# 2          False  False  False    False         False  False  False
# 3          False  False  False     True         False  False  False
# 4          False  False  False     True         False  False  False
# ...          ...    ...    ...      ...           ...    ...    ...
# 1213       False  False  False    False         False  False   True
# 1214       False  False  False    False         False  False   True
# 1215       False  False  False    False         False  False   True
# 1216         NaN    NaN    NaN      NaN           NaN    NaN   True
# 1217         NaN    NaN    NaN      NaN           NaN    NaN   True
#
#       habitat_count
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 1213            1.0
# 1214            1.0
# 1215            1.0
# 1216            1.0
# 1217            1.0
#
# [1218 rows x 17 columns]

# %%
dex[dex.habitat_count > 1]
# Out:
#        num baseSpecies      prevo        name      legendary     species  \
# 15      16      Pidgey        NaN      Pidgey            NaN      Pidgey
# 16      17   Pidgeotto     Pidgey   Pidgeotto            NaN   Pidgeotto
# 17      18     Pidgeot  Pidgeotto     Pidgeot            NaN     Pidgeot
# 18      19     Rattata        NaN     Rattata            NaN     Rattata
# 19      19     Rattata        NaN     Rattata            NaN     Rattata
# ...    ...         ...        ...         ...            ...         ...
# 1204   998  Baxcalibur   Arctibax  Baxcalibur            NaN  Baxcalibur
# 1208  1001    Wo-Chien        NaN    Wo-Chien  Sub-Legendary    Wo-Chien
# 1209  1002   Chien-Pao        NaN   Chien-Pao  Sub-Legendary   Chien-Pao
# 1210  1003     Ting-Lu        NaN     Ting-Lu  Sub-Legendary     Ting-Lu
# 1211  1004      Chi-Yu        NaN      Chi-Yu  Sub-Legendary      Chi-Yu
#
#                                                 habitat grassland forest  \
# 15    Kanto and Johtonian forests, fields, and grass...      True   True
# 16               Kantonian and Johto forests and fields      True   True
# 17           Kantonian and Johtonian forests and fields      True   True
# 18                Fields, plains, savannas, urban areas      True  False
# 19                Fields, plains, savannas, urban areas      True  False
# ...                                                 ...       ...    ...
# 1204                  Snow-packed caves, boreal forests     False   True
# 1208                                              Ruins     False  False
# 1209                                              Ruins     False  False
# 1210                                              Ruins     False  False
# 1211                                              Ruins     False  False
#
#      waters-edge    sea   cave mountain rough-terrain  urban   rare  \
# 15         False  False  False    False         False  False  False
# 16         False  False  False    False         False  False  False
# 17         False  False  False    False         False  False  False
# 18         False  False  False    False         False   True  False
# 19         False  False  False    False         False   True  False
# ...          ...    ...    ...      ...           ...    ...    ...
# 1204       False  False   True    False         False  False  False
# 1208       False  False  False    False          True  False   True
# 1209       False  False  False    False          True  False   True
# 1210       False  False  False    False          True  False   True
# 1211       False  False  False    False          True  False   True
#
#       habitat_count
# 15              2.0
# 16              2.0
# 17              2.0
# 18              2.0
# 19              2.0
# ...             ...
# 1204            2.0
# 1208            2.0
# 1209            2.0
# 1210            2.0
# 1211            2.0
#
# [489 rows x 17 columns]
