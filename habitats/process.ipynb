# %%
import pandas as pd

df = pd.read_csv("habitats.csv", index_col="Unnamed: 0")
subs = [("♀", "-F"), ("♂", "-M"), ("'", "’"), ("Flabébé", "Flabébé"), ("Daschsbun", "Dachsbun")]
for old, new in subs:
    df["species"] = df.species.str.replace(old, new)
df
# Out:
#            species                            habitat
# 0        Bulbasaur      Kantonian forests and jungles
# 1          Ivysaur      Kantonian forests and jungles
# 2         Venusaur      Kantonian forests and jungles
# 3       Charmander  Kantonian mountains and volcanoes
# 4       Charmeleon  Kantonian mountains and volcanoes
# ...            ...                                ...
# 1003        Chi-Yu                              Ruins
# 1004  Roaring Moon                          Area Zero
# 1005  Iron Valiant                          Area Zero
# 1006      Koraidon                           Anywhere
# 1007      Miraidon                           Anywhere
#
# [1008 rows x 2 columns]

# %%
dex = pd.read_csv("../dex/dex.csv")
dex = dex[dex.num > 0]
dex = dex[~dex.forme.isin(["Mega", "Mega-X", "Mega-Y", "Primal", "Gmax"])]
dex = dex[["num", "name", "baseSpecies", "prevo", "legendary"]]
dex.baseSpecies.fillna(value=dex.name, inplace=True)
dex = dex.merge(right=dex[["name", "legendary"]], how="left", left_on="baseSpecies", right_on="name", suffixes=["_1", None])
# dex.drop(columns=["name_1", "legendary_1"], inplace=True)
dex
# Out:
#        num        name_1   baseSpecies       prevo           legendary_1  \
# 0        1     Bulbasaur     Bulbasaur         NaN                   NaN
# 1        2       Ivysaur       Ivysaur   Bulbasaur                   NaN
# 2        3      Venusaur      Venusaur     Ivysaur                   NaN
# 3        4    Charmander    Charmander         NaN                   NaN
# 4        5    Charmeleon    Charmeleon  Charmander                   NaN
# ...    ...           ...           ...         ...                   ...
# 1213  1006  Iron Valiant  Iron Valiant         NaN               Paradox
# 1214  1007      Koraidon      Koraidon         NaN  Restricted Legendary
# 1215  1008      Miraidon      Miraidon         NaN  Restricted Legendary
# 1216  1009  Walking Wake  Walking Wake         NaN               Paradox
# 1217  1010   Iron Leaves   Iron Leaves         NaN               Paradox
#
#               name             legendary
# 0        Bulbasaur                   NaN
# 1          Ivysaur                   NaN
# 2         Venusaur                   NaN
# 3       Charmander                   NaN
# 4       Charmeleon                   NaN
# ...            ...                   ...
# 1213  Iron Valiant               Paradox
# 1214      Koraidon  Restricted Legendary
# 1215      Miraidon  Restricted Legendary
# 1216  Walking Wake               Paradox
# 1217   Iron Leaves               Paradox
#
# [1218 rows x 7 columns]

# %%
dex.columns
# Out:
# Index(['num', 'name_1', 'baseSpecies', 'prevo', 'legendary_1', 'name',
#        'legendary'],
#       dtype='object')

# %%
dex = dex.merge(right=df, how="left", left_on="baseSpecies", right_on="species")
dex
# Out:
#        num        name_1   baseSpecies       prevo           legendary_1  \
# 0        1     Bulbasaur     Bulbasaur         NaN                   NaN
# 1        2       Ivysaur       Ivysaur   Bulbasaur                   NaN
# 2        3      Venusaur      Venusaur     Ivysaur                   NaN
# 3        4    Charmander    Charmander         NaN                   NaN
# 4        5    Charmeleon    Charmeleon  Charmander                   NaN
# ...    ...           ...           ...         ...                   ...
# 1213  1006  Iron Valiant  Iron Valiant         NaN               Paradox
# 1214  1007      Koraidon      Koraidon         NaN  Restricted Legendary
# 1215  1008      Miraidon      Miraidon         NaN  Restricted Legendary
# 1216  1009  Walking Wake  Walking Wake         NaN               Paradox
# 1217  1010   Iron Leaves   Iron Leaves         NaN               Paradox
#
#               name             legendary       species  \
# 0        Bulbasaur                   NaN     Bulbasaur
# 1          Ivysaur                   NaN       Ivysaur
# 2         Venusaur                   NaN      Venusaur
# 3       Charmander                   NaN    Charmander
# 4       Charmeleon                   NaN    Charmeleon
# ...            ...                   ...           ...
# 1213  Iron Valiant               Paradox  Iron Valiant
# 1214      Koraidon  Restricted Legendary      Koraidon
# 1215      Miraidon  Restricted Legendary      Miraidon
# 1216  Walking Wake               Paradox           NaN
# 1217   Iron Leaves               Paradox           NaN
#
#                                 habitat
# 0         Kantonian forests and jungles
# 1         Kantonian forests and jungles
# 2         Kantonian forests and jungles
# 3     Kantonian mountains and volcanoes
# 4     Kantonian mountains and volcanoes
# ...                                 ...
# 1213                          Area Zero
# 1214                           Anywhere
# 1215                           Anywhere
# 1216                                NaN
# 1217                                NaN
#
# [1218 rows x 9 columns]

# %%
import re

habitat_map = {
    "grassland": "field|grassland|plain|meadow|scrubland",
    "forest": "forest|jungle|woodland",
    "waters-edge": "beach|lake|estuarie|pond|riverside|swamp|tropical river|wetland",
    "sea": "coast|ocean|sea",
    "cave": "cave",
    "mountain": "glacier|mountain|peak|tundra|volcano",
    "rough-terrain": "badland|wasteland|desert|rocky|ruin",
    "urban": "building|computer|human|sewer|power plant|urban",
    "rare": "unknown"
}

for habitat, keywords in habitat_map.items():
    dex[habitat] = dex.habitat.str.contains(keywords, flags=re.IGNORECASE, regex=True)

dex.loc[dex.prevo == "Eevee", "urban"] = True
dex.loc[~dex.legendary.isna(), list(habitat_map)] = False
dex.loc[~dex.legendary.isna(), "rare"] = True
dex.loc[dex.baseSpecies == "Unown", "rare"] = True
dex.loc[dex.baseSpecies == "Castform", "grassland"] = True

dex["habitat_count"] = dex[list(habitat_map)].sum(axis=1)
dex
# Out:
#        num        name_1   baseSpecies       prevo           legendary_1  \
# 0        1     Bulbasaur     Bulbasaur         NaN                   NaN
# 1        2       Ivysaur       Ivysaur   Bulbasaur                   NaN
# 2        3      Venusaur      Venusaur     Ivysaur                   NaN
# 3        4    Charmander    Charmander         NaN                   NaN
# 4        5    Charmeleon    Charmeleon  Charmander                   NaN
# ...    ...           ...           ...         ...                   ...
# 1213  1006  Iron Valiant  Iron Valiant         NaN               Paradox
# 1214  1007      Koraidon      Koraidon         NaN  Restricted Legendary
# 1215  1008      Miraidon      Miraidon         NaN  Restricted Legendary
# 1216  1009  Walking Wake  Walking Wake         NaN               Paradox
# 1217  1010   Iron Leaves   Iron Leaves         NaN               Paradox
#
#               name             legendary       species  \
# 0        Bulbasaur                   NaN     Bulbasaur
# 1          Ivysaur                   NaN       Ivysaur
# 2         Venusaur                   NaN      Venusaur
# 3       Charmander                   NaN    Charmander
# 4       Charmeleon                   NaN    Charmeleon
# ...            ...                   ...           ...
# 1213  Iron Valiant               Paradox  Iron Valiant
# 1214      Koraidon  Restricted Legendary      Koraidon
# 1215      Miraidon  Restricted Legendary      Miraidon
# 1216  Walking Wake               Paradox           NaN
# 1217   Iron Leaves               Paradox           NaN
#
#                                 habitat grassland forest waters-edge    sea  \
# 0         Kantonian forests and jungles     False   True       False  False
# 1         Kantonian forests and jungles     False   True       False  False
# 2         Kantonian forests and jungles     False   True       False  False
# 3     Kantonian mountains and volcanoes     False  False       False  False
# 4     Kantonian mountains and volcanoes     False  False       False  False
# ...                                 ...       ...    ...         ...    ...
# 1213                          Area Zero     False  False       False  False
# 1214                           Anywhere     False  False       False  False
# 1215                           Anywhere     False  False       False  False
# 1216                                NaN     False  False       False  False
# 1217                                NaN     False  False       False  False
#
#        cave mountain rough-terrain  urban   rare  habitat_count
# 0     False    False         False  False  False            1.0
# 1     False    False         False  False  False            1.0
# 2     False    False         False  False  False            1.0
# 3     False     True         False  False  False            1.0
# 4     False     True         False  False  False            1.0
# ...     ...      ...           ...    ...    ...            ...
# 1213  False    False         False  False   True            1.0
# 1214  False    False         False  False   True            1.0
# 1215  False    False         False  False   True            1.0
# 1216  False    False         False  False   True            1.0
# 1217  False    False         False  False   True            1.0
#
# [1218 rows x 19 columns]

# %%
dex["habitat_final"] = dex.habitat
dex["habitat_final"] = dex.habitat_final.str.replace("Kanto\w* ", "", regex=True)
dex["habitat_final"] = dex.habitat_final.str.replace("(\w*)(,| and) .*", "\g<1>", regex=True)
dex["habitat_final"].fillna("Rare", inplace=True)

# %%
habitat_map = {
    "Grassland": "areas with unpredictable weather|farms|gardens|grasslands|fields|meadows|pastures|plains|prairies|savannas",
    "Forest": "boreal|forest|jungles|montane|temperate|woodlands|woods",
    "Water's-edge": "beaches|lakes|marshes|ponds|rivers|streams|swamps|wetlands",
    "Sea": "coastal cliffs|cold|ocean|polar|pools|reefs|sea",
    "Cave": "cave|damp|mines",
    "Mountain": "clear skies|highlands|glaciers|mountains|peaks|peatlands|stratosphere|volcanoes",
    "Rough-terrain": "badlands|canyons|cliffs|deserts|rocky areas|ruins|wastelands",
    "Urban": "alleys|anywhere|buildings|cities|computers|heavily-polluted|graveyards|landfills|power plants|remote areas|urban",
    "Rare": "unknown",
}

for habitat, keywords in habitat_map.items():
    dex.loc[dex.habitat_final.str.contains(keywords, flags=re.IGNORECASE, regex=True), "habitat_final"] = habitat

dex.loc[dex.prevo == "Eevee", "habitat_final"] = "Urban"
dex.loc[~dex.legendary.isna(), "habitat_final"] = "Rare"
dex.habitat_final.value_counts()
# Out:
# Forest           296
# Rare             191
# Grassland        167
# Water's-edge     130
# Urban            107
# Mountain          95
# Cave              81
# Rough-terrain     78
# Sea               73
# Name: habitat_final, dtype: int64

# %%
# out = pd.read_csv("template.csv", encoding="utf-8")
# out["Species"] = out.Species.str.replace("(.*) - (F|M)", "\g<1>", regex=True)
# out = out.merge(right=dex[["name", "habitat", "habitat_final"]], how="left", left_on="Species", right_on="name")
dex[["name", "habitat", "habitat_final"]].to_csv("output.csv", index=False)

# %%
dex[dex.baseSpecies=="Meowth"]
# Out:
#     num        name_1 baseSpecies prevo legendary_1    name legendary species  \
# 76   52        Meowth      Meowth   NaN         NaN  Meowth       NaN  Meowth
# 77   52  Meowth-Alola      Meowth   NaN         NaN  Meowth       NaN  Meowth
# 78   52  Meowth-Galar      Meowth   NaN         NaN  Meowth       NaN  Meowth
#
#                             habitat grassland forest waters-edge    sea  \
# 76  Urban towns and cities, forests     False   True       False  False
# 77  Urban towns and cities, forests     False   True       False  False
# 78  Urban towns and cities, forests     False   True       False  False
#
#      cave mountain rough-terrain urban   rare  habitat_count habitat_final
# 76  False    False         False  True  False            2.0         Urban
# 77  False    False         False  True  False            2.0         Urban
# 78  False    False         False  True  False            2.0         Urban

# %%
dex[dex.name=="Rockruff"]
# Out:
#      num    name_1 baseSpecies prevo legendary_1      name legendary  \
# 891  744  Rockruff    Rockruff   NaN         NaN  Rockruff       NaN
#
#       species                                habitat grassland forest  \
# 891  Rockruff  Forests, mountains, badlands, deserts     False   True
#
#     waters-edge    sea   cave mountain rough-terrain  urban   rare  \
# 891       False  False  False     True          True  False  False
#
#      habitat_count habitat_final
# 891            3.0        Forest
