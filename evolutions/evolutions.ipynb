# %%
import pandas as pd

df = pd.read_csv("../dex/dex.csv", index_col="name")
df = df[["num", "prevo", "evoLevel", "forme", "baseSpecies", "requiredItem", "evoCondition", "evoType", "numEvos", "legendary", "eggGroup_Undiscovered", "canHatch"]]
df = df[df.num > 0]
df
# Out:
#                 num      prevo  evoLevel forme baseSpecies requiredItem  \
# name
# Bulbasaur         1        NaN       NaN   NaN         NaN          NaN
# Ivysaur           2  Bulbasaur      16.0   NaN         NaN          NaN
# Venusaur          3    Ivysaur      32.0   NaN         NaN          NaN
# Venusaur-Mega     3        NaN       NaN  Mega    Venusaur  Venusaurite
# Venusaur-Gmax     3        NaN       NaN  Gmax    Venusaur          NaN
# ...             ...        ...       ...   ...         ...          ...
# Iron Valiant   1006        NaN       NaN   NaN         NaN          NaN
# Koraidon       1007        NaN       NaN   NaN         NaN          NaN
# Miraidon       1008        NaN       NaN   NaN         NaN          NaN
# Walking Wake   1009        NaN       NaN   NaN         NaN          NaN
# Iron Leaves    1010        NaN       NaN   NaN         NaN          NaN
#
#               evoCondition evoType  numEvos             legendary  \
# name
# Bulbasaur              NaN     NaN      1.0                   NaN
# Ivysaur                NaN     NaN      1.0                   NaN
# Venusaur               NaN     NaN      NaN                   NaN
# Venusaur-Mega          NaN     NaN      NaN                   NaN
# Venusaur-Gmax          NaN     NaN      NaN                   NaN
# ...                    ...     ...      ...                   ...
# Iron Valiant           NaN     NaN      NaN               Paradox
# Koraidon               NaN     NaN      NaN  Restricted Legendary
# Miraidon               NaN     NaN      NaN  Restricted Legendary
# Walking Wake           NaN     NaN      NaN               Paradox
# Iron Leaves            NaN     NaN      NaN               Paradox
#
#                eggGroup_Undiscovered  canHatch
# name
# Bulbasaur                          0       NaN
# Ivysaur                            0       NaN
# Venusaur                           0       NaN
# Venusaur-Mega                      0       NaN
# Venusaur-Gmax                      0       NaN
# ...                              ...       ...
# Iron Valiant                       1       NaN
# Koraidon                           1       NaN
# Miraidon                           1       NaN
# Walking Wake                       1       NaN
# Iron Leaves                        1       NaN
#
# [1300 rows x 12 columns]

# %%
df["stage"] = 0
df.loc[~df.prevo.isna(), "stage"] = 1
for name in df[~df.prevo.isna()].index:
    prevo = df.loc[name, "prevo"]
    preprevo = df.loc[prevo, "prevo"]
    if not pd.isna(preprevo):
        df.loc[name, "stage"] = 2
# for name in df[~df.forme.isna() & df.forme.str.contains("Mega|Gmax", regex=True)].index:
#     baseSpecies = df.loc[name, "baseSpecies"]
#     base_stage = df.loc[baseSpecies, "stage"]
#     df.loc[name, "stage"] = base_stage + 1
df.loc[~df.forme.isna() & df.forme.str.contains("Mega"), "stage"] = "Mega"
df.loc[~df.forme.isna() & df.forme.str.contains("Gmax"), "stage"] = "Gmax"
df
# Out:
#                 num      prevo  evoLevel forme baseSpecies requiredItem  \
# name
# Bulbasaur         1        NaN       NaN   NaN         NaN          NaN
# Ivysaur           2  Bulbasaur      16.0   NaN         NaN          NaN
# Venusaur          3    Ivysaur      32.0   NaN         NaN          NaN
# Venusaur-Mega     3        NaN       NaN  Mega    Venusaur  Venusaurite
# Venusaur-Gmax     3        NaN       NaN  Gmax    Venusaur          NaN
# ...             ...        ...       ...   ...         ...          ...
# Iron Valiant   1006        NaN       NaN   NaN         NaN          NaN
# Koraidon       1007        NaN       NaN   NaN         NaN          NaN
# Miraidon       1008        NaN       NaN   NaN         NaN          NaN
# Walking Wake   1009        NaN       NaN   NaN         NaN          NaN
# Iron Leaves    1010        NaN       NaN   NaN         NaN          NaN
#
#               evoCondition evoType  numEvos             legendary  \
# name
# Bulbasaur              NaN     NaN      1.0                   NaN
# Ivysaur                NaN     NaN      1.0                   NaN
# Venusaur               NaN     NaN      NaN                   NaN
# Venusaur-Mega          NaN     NaN      NaN                   NaN
# Venusaur-Gmax          NaN     NaN      NaN                   NaN
# ...                    ...     ...      ...                   ...
# Iron Valiant           NaN     NaN      NaN               Paradox
# Koraidon               NaN     NaN      NaN  Restricted Legendary
# Miraidon               NaN     NaN      NaN  Restricted Legendary
# Walking Wake           NaN     NaN      NaN               Paradox
# Iron Leaves            NaN     NaN      NaN               Paradox
#
#                eggGroup_Undiscovered  canHatch  stage
# name
# Bulbasaur                          0       NaN      0
# Ivysaur                            0       NaN      1
# Venusaur                           0       NaN      2
# Venusaur-Mega                      0       NaN      3
# Venusaur-Gmax                      0       NaN      3
# ...                              ...       ...    ...
# Iron Valiant                       1       NaN      0
# Koraidon                           1       NaN      0
# Miraidon                           1       NaN      0
# Walking Wake                       1       NaN      0
# Iron Leaves                        1       NaN      0
#
# [1300 rows x 13 columns]

# %%
df.loc[(df.stage==0) & df.canHatch, "is_baby"] = "Baby"
df
# Out:
#                 num      prevo  evoLevel forme baseSpecies requiredItem  \
# name
# Bulbasaur         1        NaN       NaN   NaN         NaN          NaN
# Ivysaur           2  Bulbasaur      16.0   NaN         NaN          NaN
# Venusaur          3    Ivysaur      32.0   NaN         NaN          NaN
# Venusaur-Mega     3        NaN       NaN  Mega    Venusaur  Venusaurite
# Venusaur-Gmax     3        NaN       NaN  Gmax    Venusaur          NaN
# ...             ...        ...       ...   ...         ...          ...
# Iron Valiant   1006        NaN       NaN   NaN         NaN          NaN
# Koraidon       1007        NaN       NaN   NaN         NaN          NaN
# Miraidon       1008        NaN       NaN   NaN         NaN          NaN
# Walking Wake   1009        NaN       NaN   NaN         NaN          NaN
# Iron Leaves    1010        NaN       NaN   NaN         NaN          NaN
#
#               evoCondition evoType  numEvos             legendary  \
# name
# Bulbasaur              NaN     NaN      1.0                   NaN
# Ivysaur                NaN     NaN      1.0                   NaN
# Venusaur               NaN     NaN      NaN                   NaN
# Venusaur-Mega          NaN     NaN      NaN                   NaN
# Venusaur-Gmax          NaN     NaN      NaN                   NaN
# ...                    ...     ...      ...                   ...
# Iron Valiant           NaN     NaN      NaN               Paradox
# Koraidon               NaN     NaN      NaN  Restricted Legendary
# Miraidon               NaN     NaN      NaN  Restricted Legendary
# Walking Wake           NaN     NaN      NaN               Paradox
# Iron Leaves            NaN     NaN      NaN               Paradox
#
#                eggGroup_Undiscovered  canHatch  stage is_baby
# name
# Bulbasaur                          0       NaN      0     NaN
# Ivysaur                            0       NaN      1     NaN
# Venusaur                           0       NaN      2     NaN
# Venusaur-Mega                      0       NaN      3     NaN
# Venusaur-Gmax                      0       NaN      3     NaN
# ...                              ...       ...    ...     ...
# Iron Valiant                       1       NaN      0     NaN
# Koraidon                           1       NaN      0     NaN
# Miraidon                           1       NaN      0     NaN
# Walking Wake                       1       NaN      0     NaN
# Iron Leaves                        1       NaN      0     NaN
#
# [1300 rows x 14 columns]
